# %%
import  pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path="D:\MACHINE LEARNING\CLUSTERING\PROJECTS\DATASETS\\Spotify-2000.csv"
music_df=pd.read_csv(file_path)
music_df
# Out:
#       Index                   Title                    Artist  \
# 0         1                 Sunrise               Norah Jones
# 1         2             Black Night               Deep Purple
# 2         3          Clint Eastwood                  Gorillaz
# 3         4           The Pretender              Foo Fighters
# 4         5  Waitin' On A Sunny Day         Bruce Springsteen
# ...     ...                     ...                       ...
# 1989   1990        Heartbreak Hotel             Elvis Presley
# 1990   1991               Hound Dog             Elvis Presley
# 1991   1992         Johnny B. Goode               Chuck Berry
# 1992   1993               Take Five  The Dave Brubeck Quartet
# 1993   1994          Blueberry Hill               Fats Domino
#
#                 Top Genre  Year  Beats Per Minute (BPM)  Energy  Danceability  \
# 0         adult standards  2004                     157      30            53
# ...

# %%
#remove  index

# %%
music_df=music_df.drop("Index",axis=1)
music_df
# Out:
#                        Title                    Artist            Top Genre  \
# 0                    Sunrise               Norah Jones      adult standards
# 1                Black Night               Deep Purple           album rock
# 2             Clint Eastwood                  Gorillaz  alternative hip hop
# 3              The Pretender              Foo Fighters    alternative metal
# 4     Waitin' On A Sunny Day         Bruce Springsteen         classic rock
# ...                      ...                       ...                  ...
# 1989        Heartbreak Hotel             Elvis Presley      adult standards
# 1990               Hound Dog             Elvis Presley      adult standards
# 1991         Johnny B. Goode               Chuck Berry           blues rock
# 1992               Take Five  The Dave Brubeck Quartet                bebop
# 1993          Blueberry Hill               Fats Domino      adult standards
#
# ...

# %%
#basics checks

# %%
music_df.head()
# Out:
#                     Title             Artist            Top Genre  Year  \
# 0                 Sunrise        Norah Jones      adult standards  2004
# 1             Black Night        Deep Purple           album rock  2000
# 2          Clint Eastwood           Gorillaz  alternative hip hop  2001
# 3           The Pretender       Foo Fighters    alternative metal  2007
# 4  Waitin' On A Sunny Day  Bruce Springsteen         classic rock  2002
#
#    Beats Per Minute (BPM)  Energy  Danceability  Loudness (dB)  Liveness  \
# 0                     157      30            53            -14        11
# 1                     135      79            50            -11        17
# 2                     168      69            66             -9         7
# 3                     173      96            43             -4         3
# 4                     106      82            58             -5        10
#
#    Valence Length (Duration)  Acousticness  Speechiness  Popularity
# ...

# %%
music_df.tail()
# Out:
#                  Title                    Artist        Top Genre  Year  \
# 1989  Heartbreak Hotel             Elvis Presley  adult standards  1958
# 1990         Hound Dog             Elvis Presley  adult standards  1958
# 1991   Johnny B. Goode               Chuck Berry       blues rock  1959
# 1992         Take Five  The Dave Brubeck Quartet            bebop  1959
# 1993    Blueberry Hill               Fats Domino  adult standards  1959
#
#       Beats Per Minute (BPM)  Energy  Danceability  Loudness (dB)  Liveness  \
# 1989                      94      21            70            -12        11
# 1990                     175      76            36             -8        76
# 1991                     168      80            53             -9        31
# 1992                     174      26            45            -13         7
# 1993                     133      50            49            -10        16
#
#       Valence Length (Duration)  Acousticness  Speechiness  Popularity
# ...

# %%
music_df.size
# Out:
# 27916

# %%
music_df.shape
# Out:
# (1994, 14)

# %%
music_df.columns
# Out:
# Index(['Title', 'Artist', 'Top Genre', 'Year', 'Beats Per Minute (BPM)',
#        'Energy', 'Danceability', 'Loudness (dB)', 'Liveness', 'Valence',
#        'Length (Duration)', 'Acousticness', 'Speechiness', 'Popularity'],
#       dtype='object')

# %%
music_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1994 entries, 0 to 1993
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Title                   1994 non-null   object
#  1   Artist                  1994 non-null   object
#  2   Top Genre               1994 non-null   object
#  3   Year                    1994 non-null   int64
#  4   Beats Per Minute (BPM)  1994 non-null   int64
#  5   Energy                  1994 non-null   int64
#  6   Danceability            1994 non-null   int64
#  7   Loudness (dB)           1994 non-null   int64
#  8   Liveness                1994 non-null   int64
#  9   Valence                 1994 non-null   int64
#  10  Length (Duration)       1994 non-null   object
#  11  Acousticness            1994 non-null   int64
#  12  Speechiness             1994 non-null   int64
#  13  Popularity              1994 non-null   int64
# dtypes: int64(10), object(4)
# ...

# %%
#checking the null values

# %%
music_df.isnull().sum()
# Out:
# Title                     0
# Artist                    0
# Top Genre                 0
# Year                      0
# Beats Per Minute (BPM)    0
# Energy                    0
# Danceability              0
# Loudness (dB)             0
# Liveness                  0
# Valence                   0
# Length (Duration)         0
# Acousticness              0
# Speechiness               0
# Popularity                0
# dtype: int64

# %%
#no null values

# %%
#seperation of categorical and numerical columns

# %%
categorical_columns=[]
numerical_columns=[]
for i,j in dict(music_df.dtypes).items():
    if j=="O":
        categorical_columns.append(i)
    else:
        numerical_columns.append(i)

# %%
categorical_columns
# Out:
# ['Title', 'Artist', 'Top Genre', 'Length (Duration)']

# %%
numerical_columns
# Out:
# ['Year',
#  'Beats Per Minute (BPM)',
#  'Energy',
#  'Danceability',
#  'Loudness (dB)',
#  'Liveness',
#  'Valence',
#  'Acousticness',
#  'Speechiness',
#  'Popularity']

# %%
#working on the numerical columns

# %%
music_df.describe()
# Out:
#               Year  Beats Per Minute (BPM)       Energy  Danceability  \
# count  1994.000000             1994.000000  1994.000000   1994.000000
# mean   1992.992979              120.215647    59.679539     53.238215
# std      16.116048               28.028096    22.154322     15.351507
# min    1956.000000               37.000000     3.000000     10.000000
# 25%    1979.000000               99.000000    42.000000     43.000000
# 50%    1993.000000              119.000000    61.000000     53.000000
# 75%    2007.000000              136.000000    78.000000     64.000000
# max    2019.000000              206.000000   100.000000     96.000000
#
#        Loudness (dB)     Liveness      Valence  Acousticness  Speechiness  \
# count    1994.000000  1994.000000  1994.000000   1994.000000  1994.000000
# mean       -9.008526    19.012036    49.408726     28.858074     4.994985
# std         3.647876    16.727378    24.858212     29.011986     4.401566
# ...

# %%
plt.figure(figsize=(15,14))
for index,column in enumerate(numerical_columns):
    plt.subplot(4,3,index+1)
    plt.title(column)
    plt.hist(music_df[column],bins=30)

# %%
plt.figure(figsize=(16,16))
for index,column in enumerate(numerical_columns):
    plt.subplot(4,3,index+1)
    plt.title(column)
    plt.boxplot(music_df[column],vert=False)

# %%
#correlation

# %%
plt.figure(figsize=(10,10))
corr=music_df.corr(numeric_only=True)
sns.heatmap(corr,annot=True)
plt.show()

# %%
#selecting the columns

# %%
music_df.columns
# Out:
# Index(['Title', 'Artist', 'Top Genre', 'Year', 'Beats Per Minute (BPM)',
#        'Energy', 'Danceability', 'Loudness (dB)', 'Liveness', 'Valence',
#        'Length (Duration)', 'Acousticness', 'Speechiness', 'Popularity'],
#       dtype='object')

# %%
from sklearn.preprocessing import MinMaxScaler
for i in numerical_columns:
    MM=MinMaxScaler()
    music_df[i]=MM.fit_transform(music_df[[i]])

# %%
X=music_df[['Beats Per Minute (BPM)','Energy', 'Danceability', 'Loudness (dB)', 'Liveness', 'Valence',
        'Acousticness', 'Speechiness',]].

# %%
X=X.values

# %%
from sklearn.cluster import KMeans
KM=KMeans()
KM.fit(X)
# Out:
# KMeans()

# %%
import warnings

warnings.filterwarnings('ignore')

wss=[]
for i in range(1,10):
    kmeans=KMeans(n_clusters=i,max_iter=300,random_state=1234)
    kmeans.fit(X)
    wss.append(round(kmeans.inertia_,2))

# %%
wss
# Out:
# [642.52, 438.18, 360.49, 329.04, 301.77, 276.65, 263.44, 252.16, 241.72]

# %%
plt.plot(range(1,10),wss)
plt.title("The Elbow method")
plt.xlabel("clusters")
plt.ylabel("WSS")
plt.show()

# %%
kmeans=KMeans(n_clusters=3,max_iter=300,random_state=1234)
y_clusters=kmeans.fit_predict(X) # which data point belongs to which cluster
y_clusters
# Out:
# array([1, 0, 0, ..., 0, 1, 1])

# %%
plt.figure(figsize=(12,8))
plt.scatter(X[y_clusters==0,0],X[y_clusters==0,1],s=100,c='red',label="Cluster1")
plt.scatter(X[y_clusters==1,0],X[y_clusters==1,1],s=100,c='blue',label="Cluster2")
plt.scatter(X[y_clusters==2,0],X[y_clusters==2,1],s=100,c='green',label="Cluster3")
plt.scatter(kmeans.cluster_centers_[:,0],kmeans.cluster_centers_[:,1],s=300,c='yellow',label='Centriods')
plt.title("Clusters using K-means")
plt.xlabel("Annual Income")
plt.ylabel("Spending score")
plt.legend()
plt.show()
